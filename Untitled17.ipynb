# %% [markdown]
# <a href="https://colab.research.google.com/github/Suratan63011017/LeetCode/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# !pip install tensorflow==2.9
# !pip install scikit-learn
# !pip install tqdm
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting tensorflow==2.9
#   Downloading tensorflow-2.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.6.3)
# Collecting flatbuffers<2,>=1.12 (from tensorflow==2.9)
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (3.9.0)
# Collecting keras<2.10.0,>=2.9.0rc0 (from tensorflow==2.9)
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.9 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.9)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (23.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.16.0)
# Collecting tensorboard<2.10,>=2.9 (from tensorflow==2.9)
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 107.6 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (0.33.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0 (from tensorflow==2.9)
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 42.9 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.10,>=2.9->tensorflow==2.9)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (3.4.4)
# Collecting protobuf>=3.9.2 (from tensorflow==2.9)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 105.2 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 57.4 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, keras, flatbuffers, tensorflow-estimator, tensorboard-data-server, protobuf, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed flatbuffers-1.12 google-auth-oauthlib-0.4.6 keras-2.9.0 keras-preprocessing-1.1.2 protobuf-3.19.6 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.0 tensorflow-estimator-2.9.0
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)

# %%
#Array, image processing
import cv2
import numpy as np
import matplotlib.pyplot as plt
#Model Operation
from keras import Model, Input
import keras.utils as image
# from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, UpSampling2D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
# io
import glob
from tqdm import tqdm
import warnings;
warnings.filterwarnings('ignore')
import zipfile
import os
import numpy as np
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
from tensorflow.keras.preprocessing.image import load_img, img_to_array

image_paths = glob.glob("/content/drive/MyDrive/dataa/data/*/*.jpg")  # Update the path
images = []

for path in tqdm(image_paths):
    img = load_img(path, target_size=(80, 80), interpolation="nearest")
    img_array = img_to_array(img)
    images.append(img_array)
# Out:
# 100%|██████████| 3203/3203 [19:25<00:00,  2.75it/s]

# %%
images = np.array(images) / 255.0

# %%
train_x, test_x = train_test_split(images, test_size=0.3, random_state=42)
train_x, val_x = train_test_split(train_x, test_size=0.2, random_state=42)

# %%
noise_mean = 0
noise_std = 0.5
noise_factor = 0.3

# %%
noisy_train_x = train_x + (noise_factor * np.random.normal(loc=noise_mean, scale=noise_std, size=train_x.shape))
noisy_val_x = val_x + (noise_factor * np.random.normal(loc=noise_mean, scale=noise_std, size=val_x.shape))
noisy_test_x = test_x + (noise_factor * np.random.normal(loc=noise_mean, scale=noise_std, size=test_x.shape))

# %%
n = 5
plt.figure(figsize=(10, 4))

for i in range(n):
    # Original image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(noisy_train_x[i])
    plt.title("Noisy")
    plt.axis("off")

    # Noisy image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(train_x[i])
    plt.title("Original")
    plt.axis("off")

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
input_img = Input(shape=(80, 80, 3))

# %%
# Layer 1
x1 = Conv2D(256, (3, 3), activation='relu', padding='same')(input_img)

# Layer 2
x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
x3 = MaxPool2D((2, 2), strides=(2, 2))(x2)

# Layer 3
x4 = Conv2D(64, (3, 3), activation='relu', padding='same')(x3)

# Layer 4
x5 = Conv2D(64, (3, 3), activation='relu', padding='same')(x4)

x6 = UpSampling2D((2, 2))(x5)

x7 = Conv2D(128, (3, 3), activation='relu', padding='same')(x6)


x8 = Conv2D(256, (3, 3), activation='relu', padding='same')(x7)


x9 = Conv2D(3, (3, 3), activation='relu', padding='same')(x8)

# Create the autoencoder model
autoencoder = Model(input_img, x9)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mse')

# Display the model summary
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 80, 80, 3)]       0
#
#  conv2d (Conv2D)             (None, 80, 80, 256)       7168
#
#  conv2d_1 (Conv2D)           (None, 80, 80, 128)       295040
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 40, 40, 64)        73792
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        36928
#
#  up_sampling2d (UpSampling2D  (None, 80, 80, 64)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 80, 80, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 80, 80, 256)       295168
#
#  conv2d_6 (Conv2D)           (None, 80, 80, 3)         6915
#
# =================================================================
# Total params: 788,867
# Trainable params: 788,867
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=3)
history = autoencoder.fit(
    noisy_train_x,
    train_x,
    epochs=16,
    batch_size=128,
    shuffle=True,
    validation_data=(noisy_val_x, val_x),
    callbacks=[callback],
    verbose=1
)
# Out:
# Epoch 1/16
# 15/15 [==============================] - 16s 258ms/step - loss: 0.0776 - val_loss: 0.0270
# Epoch 2/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0215 - val_loss: 0.0161
# Epoch 3/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0139 - val_loss: 0.0116
# Epoch 4/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0105 - val_loss: 0.0084
# Epoch 5/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0082 - val_loss: 0.0068
# Epoch 6/16
# 15/15 [==============================] - 3s 179ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 7/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 8/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 9/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 10/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0042 - val_loss: 0.0050
# Epoch 11/16
# 15/15 [==============================] - 3s 179ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 12/16
# 15/15 [==============================] - 3s 179ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 13/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 14/16
# 15/15 [==============================] - 3s 178ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 15/16
# 15/15 [==============================] - 3s 180ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 16/16
# 15/15 [==============================] - 3s 179ms/step - loss: 0.0034 - val_loss: 0.0040

# %%
predictions_test = autoencoder.predict(noisy_test_x)
# Out:
# 31/31 [==============================] - 1s 16ms/step

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5  # Number of images to display
plt.figure(figsize=(10, 6))

for i in range(n):
    # Original image
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(test_x[i])
    plt.title('Original')
    plt.axis('off')

    # Noisy image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(noisy_test_x[i])
    plt.title('Noisy')
    plt.axis('off')

    # Reconstructed image
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(predictions_test[i])
    plt.title('Reconstructed')
    plt.axis('off')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.models import Sequential

# %%
def create_autoencoder(optimizer='adam', learning_rate=0.001, batch_size=16, epochs=2):
    model = Sequential()

    # Layer 1
    x1 = Conv2D(256, (3, 3), activation='relu', padding='same', input_shape=(80, 80, 3))(input_img)

    # Layer 2
    x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
    x3 = MaxPool2D((2, 2), strides=(2, 2))(x2)

    # Layer 3
    x4 = Conv2D(64, (3, 3), activation='relu', padding='same')(x3)

    # Layer 4
    x5 = Conv2D(64, (3, 3), activation='relu', padding='same')(x4)

    x6 = UpSampling2D((2, 2))(x5)

    x7 = Conv2D(128, (3, 3), activation='relu', padding='same')(x6)

    x8 = Conv2D(256, (3, 3), activation='relu', padding='same')(x7)

    x9 = Conv2D(3, (3, 3), activation='relu', padding='same')(x8)

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# %%
from keras.wrappers.scikit_learn import KerasRegressor
model = KerasRegressor(build_fn=create_autoencoder, epochs=2, batch_size=16, verbose=0)

# %%
opts = ['adam', 'rmsprop']  # Add more optimizers as needed
lnR = [0.001]  # Learning rates to experiment with
bs = [2, 32]  # Batch sizes to experiment with
eps = [200, 400]  # Number of epochs to experiment with


param_grid = dict(batch_size=bs, epochs=eps, optimizer=opts, learning_rate=lnR)

grid = GridSearchCV(estimator=model, verbose=10,cv=8, param_grid=param_grid)

# Run the grid search
grid_result = grid.fit(noisy_train_x, train_x)

# Display the best parameters and best score
best_params = grid_result.best_params_
best_score = grid_result.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Display mean and standard deviation of scores for each set of hyperparameters
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, std, param in zip(means, stds, params):
    print(f"Mean: {mean}, Std: {std}, Params: {param}")
# Out:
# Fitting 8 folds for each of 8 candidates, totalling 64 fits
# [CV 1/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 1/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 2.8min
# [CV 2/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 2/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 3.1min
# [CV 3/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 3/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 3.2min
# [CV 4/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 4/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 3.1min
# [CV 5/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 5/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 3.1min
# [CV 6/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 6/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 3.2min
# [CV 7/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 7/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 3.2min
# [CV 8/8; 1/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 8/8; 1/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 3.2min
# [CV 1/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 1/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 2.8min
# [CV 2/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 2/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 3.3min
# [CV 3/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 3/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 3.2min
# [CV 4/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 4/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 3.2min
# [CV 5/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 5/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 3.2min
# [CV 6/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 6/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 3.2min
# [CV 7/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 7/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 3.2min
# [CV 8/8; 2/8] START batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 8/8; 2/8] END batch_size=2, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 3.2min
# [CV 1/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 1/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 5.6min
# [CV 2/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 2/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 6.4min
# [CV 3/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 3/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 6.4min
# [CV 4/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 4/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 6.5min
# [CV 5/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 5/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 6.5min
# [CV 6/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 6/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time= 6.5min
# [CV 7/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 7/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 6.5min
# [CV 8/8; 3/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 8/8; 3/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time= 6.5min
# [CV 1/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 1/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 5.7min
# [CV 2/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 2/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 6.4min
# [CV 3/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 3/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 6.4min
# [CV 4/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 4/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 6.4min
# [CV 5/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 5/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 6.4min
# [CV 6/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 6/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time= 6.4min
# [CV 7/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 7/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 6.4min
# [CV 8/8; 4/8] START batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 8/8; 4/8] END batch_size=2, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time= 6.4min
# [CV 1/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 1/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  19.9s
# [CV 2/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 2/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  22.3s
# [CV 3/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 3/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  21.9s
# [CV 4/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 4/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  22.2s
# [CV 5/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 5/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  22.0s
# [CV 6/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 6/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  22.1s
# [CV 7/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 7/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  22.0s
# [CV 8/8; 5/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam
# [CV 8/8; 5/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  22.8s
# [CV 1/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 1/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  19.9s
# [CV 2/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 2/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  21.9s
# [CV 3/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 3/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  22.2s
# [CV 4/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 4/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  22.2s
# [CV 5/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 5/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  22.1s
# [CV 6/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 6/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  21.9s
# [CV 7/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 7/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  22.4s
# [CV 8/8; 6/8] START batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop
# [CV 8/8; 6/8] END batch_size=32, epochs=200, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  22.1s
# [CV 1/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 1/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  38.7s
# [CV 2/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 2/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  43.8s
# [CV 3/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 3/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  43.5s
# [CV 4/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 4/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  43.6s
# [CV 5/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 5/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  43.4s
# [CV 6/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 6/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.022 total time=  43.8s
# [CV 7/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 7/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  43.9s
# [CV 8/8; 7/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam
# [CV 8/8; 7/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=adam;, score=-0.023 total time=  43.3s
# [CV 1/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 1/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  38.6s
# [CV 2/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 2/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  43.4s
# [CV 3/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 3/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  43.5s
# [CV 4/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 4/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  43.6s
# [CV 5/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 5/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  43.5s
# [CV 6/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 6/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.022 total time=  43.8s
# [CV 7/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 7/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  43.8s
# [CV 8/8; 8/8] START batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop
# [CV 8/8; 8/8] END batch_size=32, epochs=400, learning_rate=0.001, optimizer=rmsprop;, score=-0.023 total time=  43.7s
# Best Parameters: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Best Score: -0.02249909215606749
# Mean: -0.022499092621728778, Std: 1.4155894379647936e-05, Params: {'batch_size': 2, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Mean: -0.022499092621728778, Std: 1.4155894379647936e-05, Params: {'batch_size': 2, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': 'rmsprop'}
# Mean: -0.022499092621728778, Std: 1.4155894379647936e-05, Params: {'batch_size': 2, 'epochs': 400, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Mean: -0.022499092621728778, Std: 1.4155894379647936e-05, Params: {'batch_size': 2, 'epochs': 400, 'learning_rate': 0.001, 'optimizer': 'rmsprop'}
# Mean: -0.02249909215606749, Std: 1.4155677765708697e-05, Params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Mean: -0.02249909215606749, Std: 1.4155677765708697e-05, Params: {'batch_size': 32, 'epochs': 200, 'learning_rate': 0.001, 'optimizer': 'rmsprop'}
# Mean: -0.02249909215606749, Std: 1.4155677765708697e-05, Params: {'batch_size': 32, 'epochs': 400, 'learning_rate': 0.001, 'optimizer': 'adam'}
# Mean: -0.02249909215606749, Std: 1.4155677765708697e-05, Params: {'batch_size': 32, 'epochs': 400, 'learning_rate': 0.001, 'optimizer': 'rmsprop'}

# %%
best_epoch = best_params['epochs']
best_batch_size = best_params['batch_size']
best_optimizer = best_params['optimizer']
best_learning_rate = best_params['learning_rate']

# %%
best_optimizer
# Out:
# 'adam'

# %%
best_learning_rate
# Out:
# 0.001

# %%
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

# %%
input_img = Input(shape=(80, 80, 3))

# %%
# Layer 1
x1 = Conv2D(256, (3, 3), activation='relu', padding='same')(input_img)

# Layer 2
x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
x3 = MaxPool2D((2, 2), strides=(2, 2))(x2)

# Layer 3
x4 = Conv2D(64, (3, 3), activation='relu', padding='same')(x3)

# Layer 4
x5 = Conv2D(64, (3, 3), activation='relu', padding='same')(x4)

x6 = UpSampling2D((2, 2))(x5)

x7 = Conv2D(128, (3, 3), activation='relu', padding='same')(x6)


x8 = Conv2D(256, (3, 3), activation='relu', padding='same')(x7)


x9 = Conv2D(3, (3, 3), activation='relu', padding='same')(x8)

# Create the autoencoder model
autoencoder = Model(input_img, x9)

autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Display the model summary
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 80, 80, 3)]       0
#
#  conv2d_462 (Conv2D)         (None, 80, 80, 256)       7168
#
#  conv2d_463 (Conv2D)         (None, 80, 80, 128)       295040
#
#  max_pooling2d_66 (MaxPoolin  (None, 40, 40, 128)      0
#  g2D)
#
#  conv2d_464 (Conv2D)         (None, 40, 40, 64)        73792
#
#  conv2d_465 (Conv2D)         (None, 40, 40, 64)        36928
#
#  up_sampling2d_66 (UpSamplin  (None, 80, 80, 64)       0
#  g2D)
#
#  conv2d_466 (Conv2D)         (None, 80, 80, 128)       73856
#
#  conv2d_467 (Conv2D)         (None, 80, 80, 256)       295168
#
#  conv2d_468 (Conv2D)         (None, 80, 80, 3)         6915
#
# =================================================================
# Total params: 788,867
# Trainable params: 788,867
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=3)
history = autoencoder.fit(
    noisy_train_x,
    train_x,
    epochs=best_epoch,
    batch_size=best_batch_size,
    shuffle=True,
    validation_data=(noisy_val_x, val_x),
    callbacks=[callback]
)
# Out:
# Epoch 1/200
# 57/57 [==============================] - 4s 53ms/step - loss: 0.0528 - val_loss: 0.0102
# Epoch 2/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0084 - val_loss: 0.0054
# Epoch 3/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0046 - val_loss: 0.0043
# Epoch 4/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 5/200
# 57/57 [==============================] - 3s 50ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 6/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 7/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 8/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 9/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 10/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 11/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 12/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 13/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 14/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 15/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 16/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 17/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0023 - val_loss: 0.0059
# Epoch 18/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 19/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 20/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 21/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 22/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 23/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 24/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 25/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 26/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 27/200
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0021 - val_loss: 0.0021

# %%
predictions_test = autoencoder.predict(noisy_test_x)
# Out:
# 31/31 [==============================] - 1s 16ms/step

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
n = 5  # Number of images to display
plt.figure(figsize=(10, 6))

for i in range(n):
    # Original image
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(test_x[i])
    plt.title('Original')
    plt.axis('off')

    # Noisy image
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(noisy_test_x[i])
    plt.title('Noisy')
    plt.axis('off')

    # Reconstructed image
    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(predictions_test[i])
    plt.title('Reconstructed')
    plt.axis('off')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
